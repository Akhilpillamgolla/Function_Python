# %% [markdown]
# # Function : This will allow us to run block of code multiple times.
# ## Def key word : Creating the function, we require a def key word for sure.
# ![image.png](attachment:image.png)
# ## Where def is a keyword that tells python that this is function.
# ## Snake 🐍  casing is used over here for name_of_function().Snake casing means we will use all lowercase letter with _. If we want to give details regarding the function you use multi line comment.
# ![image-2.png](attachment:image-2.png)
# ## Later you will write the code that needs to be executed when ever you call that function.() – we will pass arguments or function using these parentheses.
# ![image-3.png](attachment:image-3.png)
# ## We mostly use return. This will allow us to assign the output of the function to a new variable.
# ![image-4.png](attachment:image-4.png)
# ## Here return will allow us to save the result to variable.

# %% [markdown]
# Example 1:

# %%
def Name():  # Defining that this is a function.(Name = Function)
    print('Akhil')  
Name() # Calling function. () are must. also check for indentation.

# %% [markdown]
# Example of function   with arguments.

# %%
def greeting(name): # <-- passing values Seperately.
    print(f'Hello {name}'+' How are you ?')
greeting('Akhil')

# %% [markdown]
# where name is variable that is sent as arguments.If we  had mentioned argument in previous step, then we need to send some arguments we can just leave that empty. If we leave that empty, we will be getting error.

# %%
# the above code can also be written as : 
def greeting(name = 'Akhil'):  # <--  passing values in arguments
    print(f'Hello {name}'+' How are you ?')
greeting() # calling function

# %% [markdown]
# Return :
# When we try to do the return, this will actually save them as a variable.

# %%
def add(num1,num2):
    return num1 + num2 # created a function that add the values.

# %%
# function calling is done here 
add(10,20) # passing values as arguments
# we cant print this 
print(add(10,20)) # the output came from above line.

# %%
# Can also save as variable due to return
result = add(10,20) 
# we can print this 
print(result)

# %% [markdown]
# Return Vs Print : </br> The return keyword allows you to actually save the result of the output of a function as a variable. The print() function simply displays the output to you, but doesn't save it for future use. Let's explore this in more detail

# %%
# we can print and return at same time: 
def myfunc(a,b):
    print(a+b) # output of print
    return(a+b) # output of Return .No o/p in  .py script
result = myfunc(1,2) # to save this code for later purpose.
# function type in none

# %%
# if we send string in the place of int lets check 
myfunc('akh','il') # this printed 2 times as we had used print in above cell.
# Out:
# 'akhil'

# %% [markdown]
# Logic in Function

# %%
# checking given number ()
def even_check(number):
    return number % 2 == 0

# %%
even_check(20) # this is even
# Out:
# True

# %%
even_check(3) # this is odd.
# Out:
# False

# %% [markdown]
# Check if any number in a list is even

# %%
def check_even_list(num_list):
    # Go through each number
    for number in num_list:
        # Once we get a "hit" on an even number, we return True
        if number % 2 == 0:
            return True
        # Don't do anything if its not even
        else:
            pass
    # Notice the indentation! This ensures we run through the entire for loop    
    return False

# %%
check_even_list([1,2,3])
# Out:
# True

# %%
check_even_list([1,3,5])
# Out:
# False

# %% [markdown]
# Return all even numbers in a list

# %%
def check_even_list(num_list):
    
    even_numbers = []
    
    # Go through each number
    for number in num_list:
        # Once we get a "hit" on an even number, we append the even number
        if number % 2 == 0:
            even_numbers.append(number)
        # Don't do anything if its not even
        else:
            pass
    # Notice the indentation! This ensures we run through the entire for loop    
    return even_numbers

# %%
check_even_list([1,2,3,4,5,6])
# Out:
# [2, 4, 6]

# %%
check_even_list([1,3,5])
# Out:
# []

# %% [markdown]
# Tuples unpacking with functions :

# %%
# List with Tuples inside
Salary = [('Dev',100000),('support',40000),('trainee',10000)]
Salary
# Out:
# [('Dev', 100000), ('support', 40000), ('trainee', 10000)]

# %%
for pay in Salary:  # tuple with packing
    print(pay)
# Out:
# ('Dev', 100000)
# ('support', 40000)
# ('trainee', 10000)

# %%
for Role,pay in Salary:  # tuple without packing
    print(pay)
# Out:
# 100000
# 40000
# 10000

# %%
for Role,pay in Salary:  # tuple without packing
    print(Role)
# Out:
# Dev
# support
# trainee

# %%
# Rich employee 
def employee_check(Salary):
    
    # Set some max value to intially beat, like zero hours
    current_max = 0
    # Set some empty value before the loop
    Rich_Employee_In_Company = ''
    
    for Role,pay in Salary:
        if pay > current_max:
            current_max = pay
            Rich_Employee_In_Company = Role
        else:
            pass
    
    # Notice the indentation here
    return (Rich_Employee_In_Company,current_max)

# %%
employee_check(Salary)
# Out:
# ('Dev', 100000)

# %% [markdown]
# Interactions between functions: </br>
#  There will be 3 positions in the list, one of which is an 'O', a function will shuffle the list, another will take a player's guess, and finally another will check to see if it is correct. This is based on the classic carnival game of guessing which cup a red ball is under.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Refrence code
example = [1,2,3,4,5]
from random import shuffle
# Note shuffle is in-place
shuffle(example)
example
# Out:
# [1, 3, 4, 5, 2]

# %%
mylist = [' ','O',' ']
def shuffle_list(mylist):
    # Take in list, and returned shuffle versioned
    shuffle(mylist)
    
    return mylist
# Out:
# [' ', 'O', ' ']

# %%
mylist  # this dont shuffle anything

# %%
shuffle_list(mylist) # Shuffling is done here.

# %%
def player_guess():
    
    guess = ''
    
    while guess not in ['0','1','2']:
        
        # Recall input() returns a string
        guess = input("Pick a number: 0, 1, or 2:  ")
    
    return int(guess)

# %%
player_guess() # Pick a number: 0, 1, or 2 (index Number)
# this just print the guessed number.
# Out:
# 1

# %%
def check_guess(mylist,guess):
    if mylist[guess] == 'O':
        print('Correct Guess!')
    else:
        print('Wrong! Better luck next time')
        print(mylist)
# we did not call this

# %%
# Initial List
mylist = [' ','O',' ']

# Shuffle It
mixedup_list = shuffle_list(mylist)

# Get User's Guess
guess = player_guess()

# Check User's Guess
#------------------------
# Notice how this function takes in the input 
# based on the output of other functions!
check_guess(mixedup_list,guess)
# Out:
# Correct Guess!
